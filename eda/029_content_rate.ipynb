# %%
import pandas as pd
import numpy as np
import tqdm
import warnings
import matplotlib.pyplot as plt

pd.set_option("max_rows", 200)
pd.set_option("max_columns", 50)
tqdm.tqdm.pandas()
# %matplotlib inline

# %%
df = pd.read_pickle("../input/riiid-test-answer-prediction/split10/train_0.pickle")

# %%
import sys
sys.path.append("../")
# df = pd.read_pickle("../input/riiid-test-answer-prediction/split10/train_0.pickle")
df = df.sort_values(["user_id", "timestamp"])
# large_user_id = df["user_id"].value_counts()
# large_user_id = large_user_id[large_user_id > 1000] 
# df = df[df["user_id"].isin(large_user_id.index)]
# df = df[df["answered_correctly"] != -1]

# %%
df["answered_correctly"] = df["answered_correctly"].replace(-1, np.nan)

# %%
def f(series):
    return series.shift(1).cumsum().fillna(0) / np.arange(len(series))

# %%
df["target_enc_content_id"] = df.groupby("content_id")["answered_correctly"].transform(f)

# %%
df["target_enc_user_id"] = df.groupby("user_id")["answered_correctly"].transform(f)

# %%
import pickle

# %%
with open("../feature_engineering/content_user_rate_dict.pickle", "rb") as f:
    data_dict = pickle.load(f)

# %%
pd.DataFrame({"content_id": data_dict})
# Out:
#        content_id
# 0            1193
# 1            1193
# 2            1527
# 3            1308
# 4            1350
# ...           ...
# 13518        1361
# 13519        1479
# 13520        1413
# 13521        1414
# 13522        1177
#
# [13523 rows x 1 columns]

# %%
df_rate = pd.Series(data_dict).reset_index()
df_rate.columns = ["content_id", "rate"]

# %%
df_m = pd.merge(df[["user_id", "content_id", "answered_correctly"]], df_rate, how="left")

# %%
df_m.groupby("user_id").first()
# Out:
#             content_id    rate
# user_id
# 24600             7900  1205.0
# 108310            3734  1452.0
# 138650            7900  1205.0
# 301590            3931  1200.0
# 341420            4159  1196.0
# ...                ...     ...
# 2147056350        5141  1212.0
# 2147160110        4909  1380.0
# 2147375580        7900  1205.0
# 2147470770        7900  1205.0
# 2147481750        4137  1463.0
#
# [39291 rows x 2 columns]

# %%
df_m[df_m["user_id"] == 24600]
# Out:
#     user_id  content_id  answered_correctly    rate
# 0     24600        7900                 1.0  1205.0
# 1     24600        7876                 0.0  1560.0
# 2     24600         175                 1.0  1623.0
# 3     24600        1278                 1.0  1304.0
# 4     24600        2064                 0.0  1396.0
# 5     24600        2065                 1.0  1328.0
# 6     24600        2063                 0.0  1785.0
# 7     24600        3364                 0.0  1510.0
# 8     24600        3365                 0.0  1600.0
# 9     24600        3363                 0.0  1598.0
# 10    24600        2947                 0.0  1681.0
# 11    24600        2946                 0.0  1709.0
# 12    24600        2948                 0.0  1735.0
# 13    24600        2595                 0.0  1504.0
# 14    24600        2594                 0.0  1635.0
# 15    24600        2593                 0.0  1364.0
# 16    24600        4492                 0.0  1595.0
# ...

# %%
df_m[df_m["user_id"] == 108310]
# Out:
#     user_id  content_id  answered_correctly    rate
# 50   108310        3734                 0.0  1452.0
# 51   108310        4276                 1.0  1404.0
# 52   108310        3654                 1.0  1432.0
# 53   108310        4026                 0.0  1580.0
# 54   108310        6435                 0.0  1826.0
# 55   108310        6659                 0.0  1606.0
# 56   108310        4554                 1.0  1328.0
# 57   108310        4476                 1.0  1471.0
# 58   108310        6325                 1.0  1405.0
# 59   108310        5001                 1.0  1333.0
# 60   108310        9446                 1.0  1254.0
# 61   108310        4491                 1.0  1470.0
# 62   108310        5708                 0.0  1625.0
# 63   108310        4467                 1.0  1512.0
# 64   108310        9626                 1.0  1580.0
# 65   108310        3639                 1.0  1460.0
# 66   108310        5616                 0.0  1610.0
# ...
