# %%
import pandas as pd
import numpy as np
import tqdm
import warnings
import matplotlib.pyplot as plt

pd.set_option("max_rows", 200)
pd.set_option("max_columns", 50)

# %matplotlib inline

# %%
data_types_dict = {
    'row_id': 'int64',
    'timestamp': 'int64',
    'user_id': 'int32',
    'content_id': 'int16',
    'content_type_id': 'int8',
    'task_container_id': 'int16',
    'user_answer': 'int8',
    'answered_correctly': 'int8',
}


df = pd.read_pickle("../input/riiid-test-answer-prediction/split10/train_0.pickle")

# %%
import sys
sys.path.append("../")
# df = pd.read_pickle("../input/riiid-test-answer-prediction/split10/train_0.pickle")
df = df.sort_values(["user_id", "timestamp"])
# large_user_id = df["user_id"].value_counts()
# large_user_id = large_user_id[large_user_id > 1000] 
# df = df[df["user_id"].isin(large_user_id.index)]
# df = df[df["answered_correctly"] != -1]

# %%
df["answered_correctly"] = df["answered_correctly"].replace(-1, np.nan)

# %%
df["prior_question_elapsed_time_div10"] = df["prior_question_elapsed_time"] % 10

# %%
df.groupby("prior_question_elapsed_time_div10")["answered_correctly"].describe()
# Out:
#                                        count      mean       std  min  25%  \
# prior_question_elapsed_time_div10
# 0.0                                8770707.0  0.654031  0.475683  0.0  0.0
# 2.0                                      2.0  1.000000  0.000000  1.0  1.0
# 3.0                                 515521.0  0.661201  0.473302  0.0  0.0
# 6.0                                 414661.0  0.650051  0.476954  0.0  0.0
# 7.0                                  97103.0  0.721389  0.448318  0.0  0.0
# 9.0                                    364.0  0.681319  0.466607  0.0  0.0
#
#                                    50%  75%  max
# prior_question_elapsed_time_div10
# 0.0                                1.0  1.0  1.0
# 2.0                                1.0  1.0  1.0
# 3.0                                1.0  1.0  1.0
# 6.0                                1.0  1.0  1.0
# 7.0                                1.0  1.0  1.0
# 9.0                                1.0  1.0  1.0

# %%
a = df[df["prior_question_elapsed_time_div10"] == 7].groupby("content_id")["answered_correctly"].describe()

# %%
a.sort_values("count").iloc[-100:-40]
# Out:
#             count      mean       std  min   25%  50%  75%  max
# content_id
# 2665         90.0  0.622222  0.487548  0.0  0.00  1.0  1.0  1.0
# 3177         90.0  0.966667  0.180511  0.0  1.00  1.0  1.0  1.0
# 2666         90.0  0.777778  0.418069  0.0  1.00  1.0  1.0  1.0
# 2667         90.0  0.622222  0.487548  0.0  0.00  1.0  1.0  1.0
# 3477         90.0  0.922222  0.269322  0.0  1.00  1.0  1.0  1.0
# 3478         90.0  0.733333  0.444694  0.0  0.00  1.0  1.0  1.0
# 3479         90.0  0.933333  0.250841  0.0  1.00  1.0  1.0  1.0
# 3179         90.0  0.222222  0.418069  0.0  0.00  0.0  0.0  1.0
# 3178         90.0  0.422222  0.496681  0.0  0.00  0.0  1.0  1.0
# 1475         91.0  0.835165  0.373087  0.0  1.00  1.0  1.0  1.0
# 1458         91.0  0.956044  0.206133  0.0  1.00  1.0  1.0  1.0
# 3290         91.0  0.714286  0.454257  0.0  0.00  1.0  1.0  1.0
# 1477         91.0  0.923077  0.267946  0.0  1.00  1.0  1.0  1.0
# ...
