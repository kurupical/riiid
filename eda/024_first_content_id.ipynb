# %%
import pandas as pd
import numpy as np
import tqdm
import warnings
import matplotlib.pyplot as plt

pd.set_option("max_rows", 200)
pd.set_option("max_columns", 50)
tqdm.tqdm.pandas()
# %matplotlib inline

# %%
df = pd.read_pickle("../input/riiid-test-answer-prediction/split10/train_0.pickle")

# %%
import sys
sys.path.append("../")
# df = pd.read_pickle("../input/riiid-test-answer-prediction/split10/train_0.pickle")
df = df.sort_values(["user_id", "timestamp"])
# large_user_id = df["user_id"].value_counts()
# large_user_id = large_user_id[large_user_id > 1000] 
# df = df[df["user_id"].isin(large_user_id.index)]
# df = df[df["answered_correctly"] != -1]

# %%
df["answered_correctly"] = df["answered_correctly"].replace(-1, np.nan)

# %%
def f(series):
    return series.shift(1).cumsum().fillna(0) / np.arange(len(series))

# %%
df["target_enc_content_id"] = df.groupby("content_id")["answered_correctly"].transform(f)

# %%
df["first_content_id"] = df.groupby("user_id")["content_id"].transform("first")

# %%
df.groupby("first_content_id")["answered_correctly"].describe().sort_values("count", ascending=False).head(30)
# Out:
#                       count      mean       std  min  25%  50%  75%  max
# first_content_id
# 7900              3617319.0  0.663924  0.472365  0.0  0.0  1.0  1.0  1.0
# 128                491305.0  0.660321  0.473601  0.0  0.0  1.0  1.0  1.0
# 5692               117899.0  0.646808  0.477964  0.0  0.0  1.0  1.0  1.0
# 4606                19050.0  0.691339  0.461953  0.0  0.0  1.0  1.0  1.0
# 5039                14999.0  0.637509  0.480736  0.0  0.0  1.0  1.0  1.0
# 3951                14455.0  0.642477  0.479287  0.0  0.0  1.0  1.0  1.0
# 4583                13451.0  0.682254  0.465617  0.0  0.0  1.0  1.0  1.0
# 4507                13230.0  0.621693  0.484983  0.0  0.0  1.0  1.0  1.0
# 6119                12158.0  0.616713  0.486207  0.0  0.0  1.0  1.0  1.0
# 5836                12133.0  0.753235  0.431147  0.0  1.0  1.0  1.0  1.0
# 5196                11985.0  0.710138  0.453717  0.0  0.0  1.0  1.0  1.0
# 3753                11805.0  0.623973  0.484407  0.0  0.0  1.0  1.0  1.0
# ...

# %%
df[df["content_id"] == 7900]
# Out:
#          timestamp     user_id  content_id  content_type_id  \
# 0                0       24600        7900                0
# 87               0      138650        7900                0
# 1618             0      408250        7900                0
# 4106             0      745460        7900                0
# 4180             0      841970        7900                0
# ...            ...         ...         ...              ...
# 9836801          0  2146821380        7900                0
# 9836923          0  2146845160        7900                0
# 9836953          0  2146960830        7900                0
# 9837166          0  2147375580        7900                0
# 9837266          0  2147470770        7900                0
#
#          task_container_id  user_answer  answered_correctly  \
# 0                        0            0                 1.0
# 87                       0            1                 0.0
# 1618                     0            0                 1.0
# ...

# %%
df["first_part"] = df.groupby("user_id")["part"].transform("first")

# %%
df.groupby("first_part")["answered_correctly"].describe().sort_values("count", ascending=False).head(30)
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# first_part
# 5           5595757.0  0.648363  0.477481  0.0  0.0  1.0  1.0  1.0
# 1           4149080.0  0.663780  0.472415  0.0  0.0  1.0  1.0  1.0
# 2             63501.0  0.660431  0.473567  0.0  0.0  1.0  1.0  1.0
# 4             10890.0  0.636272  0.481094  0.0  0.0  1.0  1.0  1.0
# 6              8943.0  0.718439  0.449786  0.0  0.0  1.0  1.0  1.0
# 3              5776.0  0.704120  0.456477  0.0  0.0  1.0  1.0  1.0
# 7              3595.0  0.627538  0.483528  0.0  0.0  1.0  1.0  1.0
