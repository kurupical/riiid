# %%
import pickle
import sys

# %%
with open("../feature_engineering/previous_content_answer_te_300.pickle", "rb") as f:
    prev_dict = pickle.load(f)

# %%
prev_dict
# Out:
# {(2, 9.0, 2.0): 0.5210355987055016,
#  (2, 10.0, 0.0): 0.5514018691588785,
#  (2, 7898.0, 2.0): 0.5462184873949579,
#  (2, 7910.0, 2.0): 0.6162464985994398,
#  (2, 7942.0, 0.0): 0.5602605863192183,
#  (2, 7964.0, 0.0): 0.6320987654320988,
#  (2, 14529.0, -1.0): 0.7722289890377588,
#  (4, 7927.0, 0.0): 0.4289405684754522,
#  (4, 7927.0, 1.0): 0.5002649708532061,
#  (4, 7927.0, 2.0): 0.4826163818503241,
#  (4, 7927.0, 3.0): 0.6035710801053761,
#  (4, 13909.0, -1.0): 0.7830578512396694,
#  (6, 2.0, 0.0): 0.5658682634730539,
#  (6, 39.0, 0.0): 0.6620689655172414,
#  (6, 7876.0, 0.0): 0.33602278120550544,
#  (6, 7876.0, 1.0): 0.3411764705882353,
#  (6, 7876.0, 2.0): 0.3595238095238095,
#  (6, 7876.0, 3.0): 0.5046163160284547,
#  (6, 7898.0, 2.0): 0.5,
#  (6, 7903.0, 1.0): 0.7958656330749354,
#  (6, 7903.0, 3.0): 0.6143790849673203,
#  (6, 7964.0, 0.0): 0.542319749216301,
#  (6, 8317.0, -1.0): 0.7143603133159269,
#  (6, 12469.0, -1.0): 0.7716535433070866,
#  (9, 2.0, 0.0): 0.3,
# ...

# %%
sys.getsizeof(prev_dict)
# Out:
# 589928
